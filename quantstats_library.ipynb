# %%
# %matplotlib inline
import quantstats as qs

# extend pandas functionality with metrics, etc.
qs.extend_pandas()

# fetch the daily returns for a stock
stock = qs.utils.download_returns('RELIANCE.NS')

# show sharpe ratio
qs.stats.sharpe(stock)

# or using extend_pandas() :)
stock.sharpe()
# Out:
# 0.6588262924628059

# %%
qs.plots.snapshot(stock, title='Reliance Performance')

# can also be called via:
# stock.plot_snapshot(title='Facebook Performance')

# %%
# (benchmark can be a pandas Series or ticker)
qs.reports.basic(stock, "^NSEI")
# Out:
# <h4>Performance Metrics</h4>
#                     Strategy    Benchmark
# ------------------  ----------  -----------
# Start Period        1996-01-01  1996-01-01
# End Period          2022-08-30  2022-08-30
# Risk-Free Rate      0.0%        0.0%
# Time in Market      99.0%       55.0%
#
# Cumulative Return   25,076.10%  295.12%
# CAGR﹪              23.03%      5.29%
#
# Sharpe              0.66        0.4
# Sortino             1.13        0.57
# Sortino/√2          0.8         0.4
# Omega               1.16        1.16
#
# Max Drawdown        -72.44%     -59.86%
# Longest DD Days     3461        1087
#
# Gain/Pain Ratio     0.16        0.11
# Gain/Pain (1M)      0.95        0.54
#
# Payoff Ratio        1.01        1.0
# Profit Factor       1.16        1.11
# Common Sense Ratio  1.31        1.17
# CPC Index           0.6         0.58
# Tail Ratio          1.13        1.05
# Outlier Win Ratio   3.17        14.74
# Outlier Loss Ratio  2.94        4.95
#
# MTD                 5.44%       3.5%
# 3M                  2.75%       8.6%
# 6M                  15.85%      6.61%
# YTD                 11.73%      2.34%
# 1Y                  18.79%      6.31%
# 3Y (ann.)           29.24%      17.28%
# 5Y (ann.)           28.32%      12.43%
# 10Y (ann.)          22.27%      12.95%
# All-time (ann.)     23.03%      5.29%
#
# Avg. Drawdown       -7.97%      -3.53%
# Avg. Drawdown Days  74          50
# Recovery Factor     346.18      4.93
# Ulcer Index         0.32        0.12
# Serenity Index      41.02       1.1
# <h4>Strategy Visualization</h4>
