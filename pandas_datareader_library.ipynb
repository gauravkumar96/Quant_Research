# %%
import os
from datetime import datetime
import pandas_datareader.data as web

# %% [markdown]
#     The pandas datareader is a wrapper to fetch data from various sources. So in order to download the data, you don't need to download and install plugin for each and every data source.

# %% [markdown]
#     These are the following data sources for which pandas-datareader is useful :-
#
#     1. Tiingo - API Required
#
#     2. IEX - API Required
#
#     3. Alpha Vantage - API Required
#
#     4. Econdb - API NOT Required
#
#     5. Enigma - API Required
#
#     6. Quandl - API Required
#
#     7. St.Louis FED (FRED) - API NOT Required
#
#     8. Kenneth French’s data library - API NOT Required
#
#     9. World Bank - API NOT Required
#
#     10. OECD - API NOT Required
#
#     11. Eurostat - API NOT Required
#
#     12. Thrift Savings Plan - API NOT Required
#
#     13. Nasdaq Trader symbol definitions - API NOT Required
#
#     14. Stooq - API NOT Required
#
#     15. MOEX - API NOT Required
#
#     16. Naver Finance - API NOT Required
#
#     17. Yahoo Finance - API NOT Required

# %% [markdown]
# ## Econdb

# %% [markdown]
#     Econdb provides economic data from 90+ official statistical agencies. Free API allows access to the complete Econdb database of time series aggregated into datasets.

# %%
import pandas_datareader.data as web
df = web.DataReader(
    '&'.join([
        'dataset=IMF_CPI', 
        'h=Geopolitical entity (reporting)', 
        'v=TIME', 
        'from=2021-10-01', 
        'to=2022-04-01'
    ]),
    'econdb'
)

# %%
df.shape
# Out:
# (6, 233)

# %%
df
# Out:
# Frequency                            Quarterly  \
# Reference Area                         Albania
# Indicator      Consumer Price Index, All items
# Scale                                    Units
# TIME_PERIOD
# 2021-10-01                               103.1
# 2021-11-01                                 NaN
# 2021-12-01                                 NaN
# 2022-01-01                               106.8
# 2022-02-01                                 NaN
# 2022-03-01                                 NaN
#
# Frequency                                        \
# Reference Area
# Indicator      Food and non-alcoholic beverages
# Scale                                     Units
# TIME_PERIOD
# 2021-10-01                                105.1
# 2021-11-01                                  NaN
# 2021-12-01                                  NaN
# 2022-01-01                                113.7
# 2022-02-01                                  NaN
# 2022-03-01                                  NaN
#
# ...

# %%
f = web.DataReader('ticker=RGDPUS', 'econdb')
f.head()
# Out:
# TableName                                                                                                                                T10106
# SeriesCode                                                                                                                               A191RX
# Table                                                                         Table 1.1.6. Real Gross Domestic Product, Chained Dollars (A) (Q)
# Series description                                                                                                       Gross domestic product
# CL_UNIT                                                                                                                                   Level
# CL_FREQ                                                                                                                                       Q
# ...

# %% [markdown]
# ## Fred Dataset

# %% [markdown]
#     All economic data for US from 1991 consisting of treasury, gdp, cpi and many more data sources

# %%
start = datetime(2010, 1, 1)
end = datetime(2013, 1, 27)

# %%
gdp = web.DataReader('GDP', 'fred', start, end)

# %%
gdp.head()
# Out:
#                   GDP
# DATE
# 2010-01-01  14764.611
# 2010-04-01  14980.193
# 2010-07-01  15141.605
# 2010-10-01  15309.471
# 2011-01-01  15351.444

# %% [markdown]
# ## Fama French

# %% [markdown]
#     Kenneth French’s data library

# %%
from pandas_datareader.famafrench import get_available_datasets

# %%
get_available_datasets()
# Out:
# ['F-F_Research_Data_Factors',
#  'F-F_Research_Data_Factors_weekly',
#  'F-F_Research_Data_Factors_daily',
#  'F-F_Research_Data_5_Factors_2x3',
#  'F-F_Research_Data_5_Factors_2x3_daily',
#  'Portfolios_Formed_on_ME',
#  'Portfolios_Formed_on_ME_Wout_Div',
#  'Portfolios_Formed_on_ME_Daily',
#  'Portfolios_Formed_on_BE-ME',
#  'Portfolios_Formed_on_BE-ME_Wout_Div',
#  'Portfolios_Formed_on_BE-ME_Daily',
#  'Portfolios_Formed_on_OP',
#  'Portfolios_Formed_on_OP_Wout_Div',
#  'Portfolios_Formed_on_OP_Daily',
#  'Portfolios_Formed_on_INV',
#  'Portfolios_Formed_on_INV_Wout_Div',
#  'Portfolios_Formed_on_INV_Daily',
#  '6_Portfolios_2x3',
#  '6_Portfolios_2x3_Wout_Div',
#  '6_Portfolios_2x3_weekly',
#  '6_Portfolios_2x3_daily',
#  '25_Portfolios_5x5',
#  '25_Portfolios_5x5_Wout_Div',
#  '25_Portfolios_5x5_Daily',
#  '100_Portfolios_10x10',
#  '100_Portfolios_10x10_Wout_Div',
#  '100_Portfolios_10x10_Daily',
#  '6_Portfolios_ME_OP_2x3',
#  '6_Portfolios_ME_OP_2x3_Wout_Div',
# ...

# %%
ds = web.DataReader('5_Industry_Portfolios', 'famafrench')

# %%
ds[0].head()
# Out:
#          Cnsmr  Manuf  HiTec  Hlth   Other
# Date
# 2017-05   2.02   0.35   3.12  -0.25  -0.45
# 2017-06  -1.20   0.32  -2.12   5.54   4.22
# 2017-07  -0.08   2.31   4.02   0.70   1.49
# 2017-08  -1.56  -0.73   2.01   2.58  -0.38
# 2017-09   1.69   4.61   0.23   2.05   4.36

# %%
print(ds['DESCR'])
# Out:
# 5 Industry Portfolios
# ---------------------
#
# This file was created by CMPT_IND_RETS using the 202203 CRSP database. It contains value- and equal-weighted returns for 5 industry portfolios. The portfolios are constructed at the end of June. The annual returns are from January to December. Missing data are indicated by -99.99 or -999. Copyright 2022 Kenneth R. French
#
#   0 : Average Value Weighted Returns -- Monthly (59 rows x 5 cols)
#   1 : Average Equal Weighted Returns -- Monthly (59 rows x 5 cols)
#   2 : Average Value Weighted Returns -- Annual (5 rows x 5 cols)
#   3 : Average Equal Weighted Returns -- Annual (5 rows x 5 cols)
#   4 : Number of Firms in Portfolios (59 rows x 5 cols)
#   5 : Average Firm Size (59 rows x 5 cols)
#   6 : Sum of BE / Sum of ME (5 rows x 5 cols)
#   7 : Value-Weighted Average of BE/ME (5 rows x 5 cols)

# %% [markdown]
# ## World Bank

# %%
from pandas_datareader import wb

# %%
matches = wb.search('gdp.*capita.*const')

# %%
matches
# Out:
#                          id  \
# 716      6.0.GDPpc_constant
# 10389        NY.GDP.PCAP.KD
# 10391        NY.GDP.PCAP.KN
# 10393     NY.GDP.PCAP.PP.KD
# 10394  NY.GDP.PCAP.PP.KD.87
#
#                                                     name unit  \
# 716    GDP per capita, PPP (constant 2011 internation...
# 10389                 GDP per capita (constant 2015 US$)
# 10391                      GDP per capita (constant LCU)
# 10393  GDP per capita, PPP (constant 2017 internation...
# 10394  GDP per capita, PPP (constant 1987 internation...
#
#                              source  \
# 716                  LAC Equity Lab
# 10389  World Development Indicators
# 10391  World Development Indicators
# 10393  World Development Indicators
# 10394         WDI Database Archives
#
#                                               sourceNote  \
# 716    GDP per capita based on purchasing power parit...
# 10389  GDP per capita is gross domestic product divid...
# ...

# %%
dat = wb.download(indicator='NY.GDP.PCAP.KD', country=['US', 'CA', 'MX'], start=2005, end=2008)

# %%
dat
# Out:
#                     NY.GDP.PCAP.KD
# country       year
# Canada        2008    42063.633052
#               2007    42097.435120
#               2006    39776.179473
#               2005    38573.199765
# Mexico        2008     9181.399967
#               2007     9214.353534
#               2006     9142.804774
#               2005     8877.851291
# United States 2008    53688.365135
#               2007    54272.719553
#               2006    53782.297288
#               2005    52796.089816

# %% [markdown]
# ## OECD

# %%
import pandas_datareader.data as web

# %%
df = web.DataReader('TUD', 'oecd')

# %%
df
# Out:
# Country                  Australia                 Austria  \
# Frequency                   Annual                  Annual
# Measure    Percentage of employees Percentage of employees
# Time
# 2018-01-01                     NaN               26.700001
# 2019-01-01                     NaN               26.299999
# 2020-01-01                     NaN                     NaN
#
# Country                    Belgium                  Canada  \
# Frequency                   Annual                  Annual
# Measure    Percentage of employees Percentage of employees
# Time
# 2018-01-01               50.700001               26.299999
# 2019-01-01               49.099998               26.100000
# 2020-01-01                     NaN               27.200001
#
# Country             Czech Republic                 Denmark  \
# Frequency                   Annual                  Annual
# Measure    Percentage of employees Percentage of employees
# Time
# ...

# %% [markdown]
# ## Eurostat

# %%
df = web.DataReader('tran_sf_railac', 'eurostat')

# %%
df
# Out:
# UNIT                                                                                      Number  \
# ACCIDENT    Collisions of trains, including collisions with obstacles within the clearance gauge
# GEO                                                                                      Austria
# FREQ                                                                                      Annual
# TIME_PERIOD
# 2018-01-01                                                 4.0
# 2019-01-01                                                 1.0
# 2020-01-01                                                 2.0
#
# UNIT                                                             \
# ACCIDENT
# GEO         Belgium Bulgaria Switzerland Channel Tunnel Czechia
# FREQ         Annual   Annual      Annual         Annual  Annual
# TIME_PERIOD
# 2018-01-01      0.0      1.0         3.0            0.0     6.0
# 2019-01-01      2.0      4.0         4.0            0.0     7.0
# ...

# %% [markdown]
# ## Thrift Savings Plan (TSP) Fund Data

# %%
import pandas_datareader.tsp as tsp

# %%
tspreader = tsp.TSPReader(start='2015-10-1', end='2015-12-31')

# %%
tspreader.read()
# Out:
#             L Income  L 2025   L 2030  L 2035   L 2040  L 2045   L 2050  \
# Date
# 2015-12-31   17.7733     NaN  25.0635     NaN  26.5715     NaN  15.0263
# 2015-12-30   17.8066     NaN  25.2267     NaN  26.7707     NaN  15.1556
# 2015-12-29   17.8270     NaN  25.3226     NaN  26.8905     NaN  15.2319
# 2015-12-28   17.7950     NaN  25.1691     NaN  26.7015     NaN  15.1101
# 2015-12-24   17.7991     NaN  25.2052     NaN  26.7481     NaN  15.1407
# ...              ...     ...      ...     ...      ...     ...      ...
# 2015-10-07   17.6639     NaN  24.8629     NaN  26.3598     NaN  14.9063
# 2015-10-06   17.6338     NaN  24.7268     NaN  26.1898     NaN  14.7979
# 2015-10-05   17.6395     NaN  24.7571     NaN  26.2306     NaN  14.8233
# 2015-10-02   17.5707     NaN  24.4472     NaN  25.8518     NaN  14.5805
# 2015-10-01   17.5164     NaN  24.2159     NaN  25.5690     NaN  14.4009
#
#             L 2055  L 2060  L 2065   G Fund   F Fund   C Fund   S Fund  \
# Date
# ...

# %% [markdown]
# ## Nasdaq Trader Symbol

# %%
from pandas_datareader.nasdaq_trader import get_nasdaq_symbols

# %%
symbols = get_nasdaq_symbols()

# %%
symbols.loc['IBM']
# Out:
# Nasdaq Traded                                                    True
# Security Name       International Business Machines Corporation Co...
# Listing Exchange                                                    N
# Market Category
# ETF                                                             False
# Round Lot Size                                                  100.0
# Test Issue                                                      False
# Financial Status                                                  NaN
# CQS Symbol                                                        IBM
# NASDAQ Symbol                                                     IBM
# NextShares                                                      False
# Name: IBM, dtype: object

# %% [markdown]
# ## Stooq Index Data

# %%
f = web.DataReader('^DJI', 'stooq')

# %%
f
# Out:
#                 Open      High       Low     Close     Volume
# Date
# 2022-05-13  31963.86  32276.05  31862.79  32196.66  430068818
# 2022-05-12  31699.04  31914.46  31228.22  31730.30  596967045
# 2022-05-11  32123.24  32584.02  31798.86  31834.11  521732651
# 2022-05-10  32504.09  32752.17  31887.89  32160.74  493371858
# 2022-05-09  32685.17  32685.17  32121.98  32245.70  535207901
# ...              ...       ...       ...       ...        ...
# 2017-05-23  20908.67  20961.14  20896.22  20937.91  244875752
# 2017-05-22  20867.77  20914.26  20860.16  20894.83  276193710
# 2017-05-19  20698.28  20857.13  20687.94  20804.84  365125107
# 2017-05-18  20579.65  20759.20  20553.45  20663.02  422531600
# 2017-05-17  20846.17  20846.17  20601.08  20606.93  423293682
#
# [1258 rows x 5 columns]

# %% [markdown]
# ## MOEX Data

# %%
import pandas_datareader as pdr

# %%
f = pdr.get_data_moex(['USD000UTSTOM', 'MAGN'], '2020-07-02', '2020-07-07')

# %%
f
# Out:
#             ADMITTEDQUOTE  ADMITTEDVALUE  BEICLOSE  BID BOARDID BOARDNAME  \
# TRADEDATE
# 2020-07-02            NaN            NaN       NaN  NaN    CETS       NaN
# 2020-07-03            NaN            NaN       NaN  NaN    CETS       NaN
# 2020-07-06            NaN            NaN       NaN  NaN    CETS       NaN
# 2020-07-07            NaN            NaN       NaN  NaN    CETS       NaN
# 2020-07-02         37.605    670695507.0       NaN  NaN    TQBR       NaN
# 2020-07-03         37.950    517431999.5       NaN  NaN    TQBR       NaN
# 2020-07-06         38.560    640380631.5       NaN  NaN    TQBR       NaN
# 2020-07-07         38.140    781482393.5       NaN  NaN    TQBR       NaN
#
#             BUYBACKDATE  CBRCLOSE    CLOSE CLOSEAUCTIONPRICE  ... TRENDWAP  \
# TRADEDATE                                                     ...
# 2020-07-02          NaN       NaN  70.5525               NaN  ...      NaN
# ...

# %% [markdown]
# ## Naver Finance Data

# %%
df = web.DataReader('005930', 'naver', start='2019-09-10', end='2019-10-09')

# %%
df
# Out:
#              Open   High    Low  Close    Volume
# Date
# 2019-09-10  47100  47200  46550  47000   9231792
# 2019-09-11  47300  47400  46800  47150  16141619
# 2019-09-16  47000  47100  46400  47100  15550926
# 2019-09-17  47000  47100  46800  46900   7006280
# 2019-09-18  46900  47700  46800  47700  10413027
# 2019-09-19  48050  49200  47850  49150  16461413
# 2019-09-20  49400  49600  49100  49200  15460210
# 2019-09-23  49250  49300  49000  49300   7568553
# 2019-09-24  49050  49650  48850  49500   7871955
# 2019-09-25  49200  49350  48800  48900   9187141
# 2019-09-26  49000  49250  48900  49200   8494756
# 2019-09-27  48000  48700  48000  48400   8048041
# 2019-09-30  48050  49250  47900  49050   9497119
# 2019-10-01  48900  49100  48650  48850   6206035
# 2019-10-02  48350  48400  47600  47600   8382463
# 2019-10-04  47400  48650  47350  48000   9331695
# 2019-10-07  48350  48700  47650  47750   7047273
# 2019-10-08  47900  49000  47600  48900  14239367

# %% [markdown]
# ## Yahoo Finance Data

# %% [markdown]
#     yahoo - retrieve daily stock prices (high, open, close, volu,e and adjusted close)
#
#     yahoo-actions - retrieve historical corporate actions (dividends and stock splits)
#
#     yahoo-dividends - retrieve historical dividends

# %%
df = web.DataReader('GE', 'yahoo', start='2019-09-10', end='2019-10-09')

# %%
df
# Out:
#                  High        Low       Open      Close     Volume  Adj Close
# Date
# 2019-09-09  72.400002  69.839996  70.000000  71.680000  6245063.0  70.888992
# 2019-09-10  74.160004  71.199997  71.279999  73.120003  7827150.0  72.313080
# 2019-09-11  74.879997  72.480003  73.199997  74.879997  7136863.0  74.053665
# 2019-09-12  76.160004  73.760002  75.199997  74.080002  8514388.0  73.262497
# 2019-09-13  75.599998  73.120003  74.480003  74.720001  5698675.0  73.975311
# 2019-09-16  75.360001  73.360001  74.400002  75.040001  5718550.0  74.292145
# 2019-09-17  75.120003  74.000000  74.400002  74.879997  4744250.0  74.133713
# 2019-09-18  75.120003  73.440002  74.480003  75.040001  5033838.0  74.292145
# 2019-09-19  76.000000  74.720001  74.800003  75.360001  4241913.0  74.608948
# 2019-09-20  76.320000  74.720001  75.680000  74.959999  7191300.0  74.212929
# 2019-09-23  75.120003  73.599998  73.760002  74.720001  4188888.0  73.975311
# ...
